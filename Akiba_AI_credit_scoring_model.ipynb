# %% [markdown]
# <a href="https://colab.research.google.com/github/SKitavi/akiba-ai/blob/main/Akiba_AI_credit_scoring_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Akiba AI Credit Risk Scoring for African SACCOs**

# %% [markdown]
# ##**Project Overview**
#
# AkibaAI is an offline-based XGBoost classifier model for credit risk scoring using mobile money transaction data.

# %% [markdown]
# ## **Objectives**

# %% [markdown]
# # **1. Data Collection & Preparation**

# %% [markdown]
# ## Data Description

# %% [markdown]
# ## Importing Libraries

# %% [markdown]
# # **2. Data Loading and Preview**
